# %% [markdown]
# ### Import Libs :

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, mean, lead, avg, lag
from dotenv import load_dotenv
import os
from pyspark.sql.window import Window

load_dotenv()
# Out:
# False

# %% [markdown]
# ### Create Spark Session :

# %%
spark = (
    SparkSession.builder
    .appName("App")
    .getOrCreate()
)
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/01/21 09:54:56 WARN Utils: Your hostname, rachid-Latitude-5580, resolves to a loopback address: 127.0.1.1; using 192.168.68.108 instead (on interface wlp1s0)
# 26/01/21 09:54:56 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/01/21 09:55:01 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %% [markdown]
# ### Load Data Brut :

# %%
def load_data():
    output_path = "../../Data/Normal/btc_minute_data.parquet"
    df = spark.read.parquet(output_path)
    return df

df = load_data()
df.count()
# Out:
# 1000

# %% [markdown]
# ### Save Bronze Data :

# %%
def Save_Bronze_Local(Data_i):
    Data_i.write.mode('overwrite').format("parquet").save("../../Data/Bronze/")
    
Save_Bronze_Local(df)

# %% [markdown]
# ### Check Null Values :

# %%
def CheckNull(Data_B):
    num_rows = Data_B.count()       
    Columns_list = Data_B.columns

    for c in Columns_list:
        num_null = Data_B.filter(col(c).isNull()).count()
        if num_null > 0:
            null_percent = (num_null / num_rows) * 100
            print(f"Column {c} has {num_null} null values ({null_percent:.2f}%)")
            
            if null_percent < 5:
                Data_B = Data_B.na.drop(subset=[c])
            else:
                try:
                    mean_value = Data_B.select(mean(c)).collect()[0][0]
                    Data_B = Data_B.fillna({c: mean_value})
                except:
                    mode_value = Data_B.groupBy(c).count().orderBy(col("count").desc()).first()[0]
                    Data_B = Data_B.fillna({c: mode_value})
        else:
            print(f"{c} : you dont have any null values")
    return Data_B

CheckNull(df)
# Out:
# open_time : you dont have any null values
# open : you dont have any null values
# high : you dont have any null values
# low : you dont have any null values
# close : you dont have any null values
# volume : you dont have any null values
# close_time : you dont have any null values
# quote_asset_volume : you dont have any null values
# number_of_trades : you dont have any null values
# taker_buy_base_volume : you dont have any null values
# taker_buy_quote_volume : you dont have any null values
# ignore : you dont have any null values
# DataFrame[open_time: timestamp_ntz, open: double, high: double, low: double, close: double, volume: double, close_time: timestamp_ntz, quote_asset_volume: double, number_of_trades: bigint, taker_buy_base_volume: double, taker_buy_quote_volume: double, ignore: string]

# %% [markdown]
# ### Check duplicated Values :

# %%
def CheckDuplicated(Data_B):
    num_rows = Data_B.count()
    num_rows_no_duplicate = Data_B.distinct().count()
    num_duplicate_values = num_rows - num_rows_no_duplicate
    if num_duplicate_values == 0:
        print("you don't have any duplicated values !!")
    else:
        Data_B = Data_B.distinct()
        return Data_B
    return Data_B

CheckDuplicated(df)
# Out:
# you don't have any duplicated values !!
# DataFrame[open_time: timestamp_ntz, open: double, high: double, low: double, close: double, volume: double, close_time: timestamp_ntz, quote_asset_volume: double, number_of_trades: bigint, taker_buy_base_volume: double, taker_buy_quote_volume: double, ignore: string]

# %% [markdown]
# ### Rmove ignore column

# %%
def Ignore_Remover(Data_B):
    Data_B = Data_B.drop(col("ignore"))
    return Data_B

df = Ignore_Remover(df)
df.printSchema()
# Out:
# root
#  |-- open_time: timestamp_ntz (nullable = true)
#  |-- open: double (nullable = true)
#  |-- high: double (nullable = true)
#  |-- low: double (nullable = true)
#  |-- close: double (nullable = true)
#  |-- volume: double (nullable = true)
#  |-- close_time: timestamp_ntz (nullable = true)
#  |-- quote_asset_volume: double (nullable = true)
#  |-- number_of_trades: long (nullable = true)
#  |-- taker_buy_base_volume: double (nullable = true)
#  |-- taker_buy_quote_volume: double (nullable = true)

# %% [markdown]
# ### Create Column close_t_plus_10

# %%
def Create_Column_close_t_plus_10(Data_B):
    window = Window.orderBy("open_time")
    Data_B = Data_B.withColumn("close_t_plus_10", lead("close", 10).over(window))
    return Data_B

df = Create_Column_close_t_plus_10(df)

# %% [markdown]
# ### Check Null After Add  close_t_plus_10 Column:

# %%
df = CheckNull(df)
# Out:
# open_time : you dont have any null values
# open : you dont have any null values
# high : you dont have any null values
# low : you dont have any null values
# close : you dont have any null values
# volume : you dont have any null values
# close_time : you dont have any null values
# quote_asset_volume : you dont have any null values
# number_of_trades : you dont have any null values
# taker_buy_base_volume : you dont have any null values
# taker_buy_quote_volume : you dont have any null values
# 26/01/21 09:55:21 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:21 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:21 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:21 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# Column close_t_plus_10 has 10 null values (1.00%)

# %% [markdown]
# ### Create Entry Variable :
# Instruction : calculer la variation relative du prix de clôture par rapport à la minute précédente pour chaque ligne du dataset. (lag et over)

# %%
def Entry_Creator(Data_B):

    windowSpec = Window.orderBy("open_time")

    Data_B = Data_B.withColumn(
        "prev_close",
        lag("close", 1).over(windowSpec)
    )

    Data_B = Data_B.withColumn(
        "return",
        (col("close") - col("prev_close")) / col("prev_close")
    )

    return Data_B


df = Entry_Creator(df)
df.show()
# Out:
# 26/01/21 09:55:22 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:22 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:22 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:22 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:22 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:22 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:22 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:22 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:22 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# +-------------------+--------+--------+--------+--------+-------+--------------------+------------------+----------------+---------------------+----------------------+---------------+----------+--------------------+
# |          open_time|    open|    high|     low|   close| volume|          close_time|quote_asset_volume|number_of_trades|taker_buy_base_volume|taker_buy_quote_volume|close_t_plus_10|prev_close|              return|
# +-------------------+--------+--------+--------+--------+-------+--------------------+------------------+----------------+---------------------+----------------------+---------------+----------+--------------------+
# |2026-01-18 21:39:00|95387.81|95387.81|95380.76|95380.76| 0.5782|2026-01-18 21:39:...|     55152.8057001|             711|              0.11958|         11406.4454078|       95424.79|      NULL|                NULL|
# |2026-01-18 21:40:00|95380.77|95380.77|95380.76|95380.77|0.44398|2026-01-18 21:40:...|     42347.1505478|             102|               0.0723|           6896.029671|       95412.86|  95380.76|1.048429474593537...|
# |2026-01-18 21:41:00|95380.76|95380.77|95380.76|95380.76|0.30774|2026-01-18 21:41:...|     29352.4770786|              81|              0.19962|         19039.9093074|        95400.0|  95380.77|-1.04842936467311...|
# |2026-01-18 21:42:00|95380.76|95380.77|95380.76|95380.77|0.72132|2026-01-18 21:42:...|     68800.0544641|              94|              0.46609|         44456.0230893|       95380.01|  95380.76|1.048429474593537...|
# |2026-01-18 21:43:00|95380.77|95380.77|95380.76|95380.77|1.75966|2026-01-18 21:43:...|    167837.7167962|             133|              0.86546|         82548.2412042|       95412.52|  95380.77|                 0.0|
# |2026-01-18 21:44:00|95380.76|95399.87|95380.76|95399.86|4.11808|2026-01-18 21:44:...|     392791.993808|             729|              2.70892|        258385.1703248|       95412.51|  95380.77|2.001451655296608...|
# |2026-01-18 21:45:00|95399.86|95430.31|95399.86| 95430.3| 4.5458|2026-01-18 21:45:...|    433700.1439777|            1674|              4.12615|        393664.8789422|        95430.3|  95399.86|3.190780363828870...|
# |2026-01-18 21:46:00|95430.31|95430.31| 95430.3| 95430.3|0.48149|2026-01-18 21:46:...|     45948.7366327|             238|              0.14857|         14178.0811567|        95430.3|   95430.3|                 0.0|
# |2026-01-18 21:47:00|95430.31|95430.31|95424.79|95424.79|0.95605|2026-01-18 21:47:...|     91234.8300638|             486|              0.11952|         11405.1913989|       95420.67|   95430.3|-5.77384750965816...|
# |2026-01-18 21:48:00| 95424.8| 95424.8|95424.79|95424.79|1.02953|2026-01-18 21:48:...|     98242.6850791|             196|              0.10304|           9832.571392|       95420.68|  95424.79|                 0.0|
# |2026-01-18 21:49:00| 95424.8| 95424.8|95424.79|95424.79|0.25145|2026-01-18 21:49:...|     23994.5650214|              87|              0.15759|          15037.994232|       95430.44|  95424.79|                 0.0|
# |2026-01-18 21:50:00|95424.79| 95424.8|95412.86|95412.86|0.58562|2026-01-18 21:50:...|     55879.6210637|             910|              0.10875|          10376.611924|       95420.68|  95424.79|-1.25019924067876...|
# |2026-01-18 21:51:00|95412.86|95412.87| 95400.0| 95400.0|3.18025|2026-01-18 21:51:...|    303433.4691274|             439|              2.15051|        205186.3310637|       95420.68|  95412.86|-1.34782669757520...|
# |2026-01-18 21:52:00|95400.01|95400.01| 95380.0|95380.01|0.79154|2026-01-18 21:52:...|     75501.0624338|             688|              0.13619|         12990.5850822|       95412.87|   95400.0|-2.09538784067140...|
# |2026-01-18 21:53:00|95380.01|95412.52| 95380.0|95412.52|3.12118|2026-01-18 21:53:...|    297753.5870847|             867|              2.38272|        227298.0526535|       95436.73|  95380.01|3.408471020291287E-4|
# |2026-01-18 21:54:00|95412.51|95412.52|95412.51|95412.51|2.71541|2026-01-18 21:54:...|    259084.0868219|             199|              0.30428|         29032.1215856|       95436.72|  95412.52|-1.04808048349558...|
# |2026-01-18 21:55:00|95412.51|95430.31| 95412.5| 95430.3|4.82859|2026-01-18 21:55:...|     460719.264393|            1269|              4.49775|        429148.0712264|       95440.31|  95412.51|1.864535373821331...|
# |2026-01-18 21:56:00| 95430.3|95430.31| 95430.3| 95430.3|0.74511|2026-01-18 21:56:...|     71106.0739491|             142|              0.31161|         29737.0388991|       95465.98|   95430.3|                 0.0|
# |2026-01-18 21:57:00| 95430.3|95430.31|95420.67|95420.67|1.94868|2026-01-18 21:57:...|    185961.0200785|             532|              0.46079|          43973.312937|       95465.97|   95430.3|-1.00911345767588...|
# |2026-01-18 21:58:00|95420.67|95420.68|95420.67|95420.68|1.14835|2026-01-18 21:58:...|    109576.3348655|             153|               0.8471|          80830.858028|        95465.0|  95420.67|1.047990964092089...|
# +-------------------+--------+--------+--------+--------+-------+--------------------+------------------+----------------+---------------------+----------------------+---------------+----------+--------------------+
# only showing top 20 rows

# %% [markdown]
# ### Check Null Values After Added return Column :

# %%
df = CheckNull(df)
# Out:
# 26/01/21 09:55:22 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:22 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:22 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:22 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:22 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:22 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:22 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:22 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:22 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:22 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:22 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:22 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# open_time : you dont have any null values
# open : you dont have any null values
# high : you dont have any null values
# 26/01/21 09:55:23 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:23 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:23 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:23 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:23 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:23 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:23 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:23 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# low : you dont have any null values
# close : you dont have any null values
# 26/01/21 09:55:23 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:23 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:23 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:23 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:23 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:23 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:23 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:23 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:23 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:23 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:23 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:23 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# volume : you dont have any null values
# close_time : you dont have any null values
# 26/01/21 09:55:23 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:23 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:23 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:23 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:24 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:24 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:24 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:24 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# quote_asset_volume : you dont have any null values
# number_of_trades : you dont have any null values
# 26/01/21 09:55:24 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:24 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:24 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:24 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:24 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:24 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# taker_buy_base_volume : you dont have any null values
# taker_buy_quote_volume : you dont have any null values
# 26/01/21 09:55:24 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:24 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:24 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:24 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:24 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:24 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# close_t_plus_10 : you dont have any null values
# Column prev_close has 1 null values (0.10%)
# 26/01/21 09:55:24 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:24 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:24 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:24 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:24 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:24 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:24 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:24 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:24 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:24 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:24 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:24 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:24 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:24 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:24 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:24 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# return : you dont have any null values

# %% [markdown]
# ### Create Entry M_5 :
# Instruction : pour chaque minute, calculer la moyenne des prix de clôture sur les 10 dernières minutes pour lisser les variations à court terme (avg , over et rowsBetween)

# %%
def MA5_Creator(Data_B):
    window = Window.orderBy("open_time")
    Window_5 = window.rowsBetween(-5, -1)
    Data_B = Data_B.withColumn("MA_5", avg(col("close")).over(Window_5))
    return Data_B
git pull --rebase

df = MA5_Creator(df)

# %% [markdown]
# ### Create Entry M_10 :
# Instruction : pour chaque minute, calculer la moyenne des prix de clôture sur les 10 dernières minutes pour lisser les variations à court terme (avg , over et rowsBetween)

# %%
def MA10_Creator(Data_B):
    window = Window.orderBy("open_time")
    Window_10 = window.rowsBetween(-10, -1)
    Data_B = Data_B.withColumn("MA_10", avg(col("close")).over(Window_10))
    return Data_B

df = MA10_Creator(df)

# %%
df.show()
# Out:
# 26/01/21 09:55:25 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:25 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:25 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:25 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:25 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:25 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:25 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:25 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:25 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:25 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:25 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:25 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:25 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# +-------------------+--------+--------+--------+--------+-------+--------------------+------------------+----------------+---------------------+----------------------+---------------+----------+--------------------+-----------------+-----------------+
# |          open_time|    open|    high|     low|   close| volume|          close_time|quote_asset_volume|number_of_trades|taker_buy_base_volume|taker_buy_quote_volume|close_t_plus_10|prev_close|              return|             MA_5|            MA_10|
# +-------------------+--------+--------+--------+--------+-------+--------------------+------------------+----------------+---------------------+----------------------+---------------+----------+--------------------+-----------------+-----------------+
# |2026-01-18 21:40:00|95380.77|95380.77|95380.76|95380.77|0.44398|2026-01-18 21:40:...|     42347.1505478|             102|               0.0723|           6896.029671|       95412.86|  95380.76|1.048429474593537...|             NULL|             NULL|
# |2026-01-18 21:41:00|95380.76|95380.77|95380.76|95380.76|0.30774|2026-01-18 21:41:...|     29352.4770786|              81|              0.19962|         19039.9093074|        95400.0|  95380.77|-1.04842936467311...|         95380.77|         95380.77|
# |2026-01-18 21:42:00|95380.76|95380.77|95380.76|95380.77|0.72132|2026-01-18 21:42:...|     68800.0544641|              94|              0.46609|         44456.0230893|       95380.01|  95380.76|1.048429474593537...|        95380.765|        95380.765|
# |2026-01-18 21:43:00|95380.77|95380.77|95380.76|95380.77|1.75966|2026-01-18 21:43:...|    167837.7167962|             133|              0.86546|         82548.2412042|       95412.52|  95380.77|                 0.0|95380.76666666666|95380.76666666666|
# |2026-01-18 21:44:00|95380.76|95399.87|95380.76|95399.86|4.11808|2026-01-18 21:44:...|     392791.993808|             729|              2.70892|        258385.1703248|       95412.51|  95380.77|2.001451655296608...|       95380.7675|       95380.7675|
# |2026-01-18 21:45:00|95399.86|95430.31|95399.86| 95430.3| 4.5458|2026-01-18 21:45:...|    433700.1439777|            1674|              4.12615|        393664.8789422|        95430.3|  95399.86|3.190780363828870...|        95384.586|        95384.586|
# |2026-01-18 21:46:00|95430.31|95430.31| 95430.3| 95430.3|0.48149|2026-01-18 21:46:...|     45948.7366327|             238|              0.14857|         14178.0811567|        95430.3|   95430.3|                 0.0|        95394.492|        95392.205|
# |2026-01-18 21:47:00|95430.31|95430.31|95424.79|95424.79|0.95605|2026-01-18 21:47:...|     91234.8300638|             486|              0.11952|         11405.1913989|       95420.67|   95430.3|-5.77384750965816...|          95404.4|95397.64714285715|
# |2026-01-18 21:48:00| 95424.8| 95424.8|95424.79|95424.79|1.02953|2026-01-18 21:48:...|     98242.6850791|             196|              0.10304|           9832.571392|       95420.68|  95424.79|                 0.0|        95413.204|95401.04000000001|
# |2026-01-18 21:49:00| 95424.8| 95424.8|95424.79|95424.79|0.25145|2026-01-18 21:49:...|     23994.5650214|              87|              0.15759|          15037.994232|       95430.44|  95424.79|                 0.0|        95422.008| 95403.6788888889|
# |2026-01-18 21:50:00|95424.79| 95424.8|95412.86|95412.86|0.58562|2026-01-18 21:50:...|     55879.6210637|             910|              0.10875|          10376.611924|       95420.68|  95424.79|-1.25019924067876...|95426.99399999999|95405.79000000001|
# |2026-01-18 21:51:00|95412.86|95412.87| 95400.0| 95400.0|3.18025|2026-01-18 21:51:...|    303433.4691274|             439|              2.15051|        205186.3310637|       95420.68|  95412.86|-1.34782669757520...|        95423.506|95408.99900000001|
# |2026-01-18 21:52:00|95400.01|95400.01| 95380.0|95380.01|0.79154|2026-01-18 21:52:...|     75501.0624338|             688|              0.13619|         12990.5850822|       95412.87|   95400.0|-2.09538784067140...|        95417.446|95410.92300000001|
# |2026-01-18 21:53:00|95380.01|95412.52| 95380.0|95412.52|3.12118|2026-01-18 21:53:...|    297753.5870847|             867|              2.38272|        227298.0526535|       95436.73|  95380.01|3.408471020291287E-4|         95408.49|        95410.847|
# |2026-01-18 21:54:00|95412.51|95412.52|95412.51|95412.51|2.71541|2026-01-18 21:54:...|    259084.0868219|             199|              0.30428|         29032.1215856|       95436.72|  95412.52|-1.04808048349558...|95406.03600000001|        95414.022|
# |2026-01-18 21:55:00|95412.51|95430.31| 95412.5| 95430.3|4.82859|2026-01-18 21:55:...|     460719.264393|            1269|              4.49775|        429148.0712264|       95440.31|  95412.51|1.864535373821331...|         95403.58|        95415.287|
# |2026-01-18 21:56:00| 95430.3|95430.31| 95430.3| 95430.3|0.74511|2026-01-18 21:56:...|     71106.0739491|             142|              0.31161|         29737.0388991|       95465.98|   95430.3|                 0.0|        95407.068|95415.28700000001|
# |2026-01-18 21:57:00| 95430.3|95430.31|95420.67|95420.67|1.94868|2026-01-18 21:57:...|    185961.0200785|             532|              0.46079|          43973.312937|       95465.97|   95430.3|-1.00911345767588...|        95413.128|95415.28700000001|
# |2026-01-18 21:58:00|95420.67|95420.68|95420.67|95420.68|1.14835|2026-01-18 21:58:...|    109576.3348655|             153|               0.8471|          80830.858028|        95465.0|  95420.67|1.047990964092089...|         95421.26|95414.87500000001|
# |2026-01-18 21:59:00|95420.67|95430.45|95420.67|95430.44|1.56906|2026-01-18 21:59:...|    149729.4237569|             528|              1.25205|         119477.032599|        95465.0|  95420.68|1.022839074298078...|95422.89199999999|        95414.464|
# +-------------------+--------+--------+--------+--------+-------+--------------------+------------------+----------------+---------------------+----------------------+---------------+----------+--------------------+-----------------+-----------------+
# only showing top 20 rows

# %% [markdown]
# ### Check Null Values After Added MA_10 and MA_5 Columns :

# %%
df = CheckNull(df)
# Out:
# 26/01/21 09:55:25 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:25 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:25 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:25 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:25 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:25 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:25 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:25 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:25 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:25 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:25 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:25 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:25 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:25 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:25 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:25 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:25 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:25 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:25 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:25 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:25 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:25 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:25 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:25 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# open_time : you dont have any null values
# open : you dont have any null values
# 26/01/21 09:55:25 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:25 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:25 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:25 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:25 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:25 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:25 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:25 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# high : you dont have any null values
# low : you dont have any null values
# 26/01/21 09:55:25 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:25 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:25 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:25 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# close : you dont have any null values
# volume : you dont have any null values
# 26/01/21 09:55:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# close_time : you dont have any null values
# quote_asset_volume : you dont have any null values
# 26/01/21 09:55:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# number_of_trades : you dont have any null values
# taker_buy_base_volume : you dont have any null values
# 26/01/21 09:55:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:26 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# taker_buy_quote_volume : you dont have any null values
# close_t_plus_10 : you dont have any null values
# 26/01/21 09:55:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# prev_close : you dont have any null values
# return : you dont have any null values
# 26/01/21 09:55:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# Column MA_5 has 1 null values (0.10%)
# MA_10 : you dont have any null values
# 26/01/21 09:55:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.

# %% [markdown]
# ### Create Entry takerratio :
# Instruction : mesurer la proportion de BTC acheté par les “takers” par rapport au volume total échangé pendant la minute.

# %%
def takerratio_creator(Data_B):
    Data_B = Data_B.withColumn("taker_ratio", col("taker_buy_base_volume") / col("volume"))
    return Data_B

df = takerratio_creator(df)
df.show()
df.printSchema()
# Out:
# 26/01/21 09:55:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:27 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# +-------------------+--------+--------+--------+--------+-------+--------------------+------------------+----------------+---------------------+----------------------+---------------+----------+--------------------+-----------------+-----------------+-------------------+
# |          open_time|    open|    high|     low|   close| volume|          close_time|quote_asset_volume|number_of_trades|taker_buy_base_volume|taker_buy_quote_volume|close_t_plus_10|prev_close|              return|             MA_5|            MA_10|        taker_ratio|
# +-------------------+--------+--------+--------+--------+-------+--------------------+------------------+----------------+---------------------+----------------------+---------------+----------+--------------------+-----------------+-----------------+-------------------+
# |2026-01-18 21:41:00|95380.76|95380.77|95380.76|95380.76|0.30774|2026-01-18 21:41:...|     29352.4770786|              81|              0.19962|         19039.9093074|        95400.0|  95380.77|-1.04842936467311...|         95380.77|         95380.77| 0.6486644570091635|
# |2026-01-18 21:42:00|95380.76|95380.77|95380.76|95380.77|0.72132|2026-01-18 21:42:...|     68800.0544641|              94|              0.46609|         44456.0230893|       95380.01|  95380.76|1.048429474593537...|        95380.765|        95380.765| 0.6461625908057451|
# |2026-01-18 21:43:00|95380.77|95380.77|95380.76|95380.77|1.75966|2026-01-18 21:43:...|    167837.7167962|             133|              0.86546|         82548.2412042|       95412.52|  95380.77|                 0.0|95380.76666666666|95380.76666666666|  0.491833649682325|
# |2026-01-18 21:44:00|95380.76|95399.87|95380.76|95399.86|4.11808|2026-01-18 21:44:...|     392791.993808|             729|              2.70892|        258385.1703248|       95412.51|  95380.77|2.001451655296608...|       95380.7675|       95380.7675| 0.6578114072577512|
# |2026-01-18 21:45:00|95399.86|95430.31|95399.86| 95430.3| 4.5458|2026-01-18 21:45:...|    433700.1439777|            1674|              4.12615|        393664.8789422|        95430.3|  95399.86|3.190780363828870...|        95384.586|        95384.586| 0.9076840160147829|
# |2026-01-18 21:46:00|95430.31|95430.31| 95430.3| 95430.3|0.48149|2026-01-18 21:46:...|     45948.7366327|             238|              0.14857|         14178.0811567|        95430.3|   95430.3|                 0.0|        95394.492|        95392.205| 0.3085630023468816|
# |2026-01-18 21:47:00|95430.31|95430.31|95424.79|95424.79|0.95605|2026-01-18 21:47:...|     91234.8300638|             486|              0.11952|         11405.1913989|       95420.67|   95430.3|-5.77384750965816...|          95404.4|95397.64714285715|0.12501438209298676|
# |2026-01-18 21:48:00| 95424.8| 95424.8|95424.79|95424.79|1.02953|2026-01-18 21:48:...|     98242.6850791|             196|              0.10304|           9832.571392|       95420.68|  95424.79|                 0.0|        95413.204|95401.04000000001| 0.1000845045797597|
# |2026-01-18 21:49:00| 95424.8| 95424.8|95424.79|95424.79|0.25145|2026-01-18 21:49:...|     23994.5650214|              87|              0.15759|          15037.994232|       95430.44|  95424.79|                 0.0|        95422.008| 95403.6788888889| 0.6267249950288328|
# |2026-01-18 21:50:00|95424.79| 95424.8|95412.86|95412.86|0.58562|2026-01-18 21:50:...|     55879.6210637|             910|              0.10875|          10376.611924|       95420.68|  95424.79|-1.25019924067876...|95426.99399999999|95405.79000000001|0.18570062497865508|
# |2026-01-18 21:51:00|95412.86|95412.87| 95400.0| 95400.0|3.18025|2026-01-18 21:51:...|    303433.4691274|             439|              2.15051|        205186.3310637|       95420.68|  95412.86|-1.34782669757520...|        95423.506|95408.99900000001| 0.6762078452951812|
# |2026-01-18 21:52:00|95400.01|95400.01| 95380.0|95380.01|0.79154|2026-01-18 21:52:...|     75501.0624338|             688|              0.13619|         12990.5850822|       95412.87|   95400.0|-2.09538784067140...|        95417.446|95410.92300000001|0.17205700280465927|
# |2026-01-18 21:53:00|95380.01|95412.52| 95380.0|95412.52|3.12118|2026-01-18 21:53:...|    297753.5870847|             867|              2.38272|        227298.0526535|       95436.73|  95380.01|3.408471020291287E-4|         95408.49|        95410.847| 0.7634035845417438|
# |2026-01-18 21:54:00|95412.51|95412.52|95412.51|95412.51|2.71541|2026-01-18 21:54:...|    259084.0868219|             199|              0.30428|         29032.1215856|       95436.72|  95412.52|-1.04808048349558...|95406.03600000001|        95414.022|0.11205674281231932|
# |2026-01-18 21:55:00|95412.51|95430.31| 95412.5| 95430.3|4.82859|2026-01-18 21:55:...|     460719.264393|            1269|              4.49775|        429148.0712264|       95440.31|  95412.51|1.864535373821331...|         95403.58|        95415.287| 0.9314831037632103|
# |2026-01-18 21:56:00| 95430.3|95430.31| 95430.3| 95430.3|0.74511|2026-01-18 21:56:...|     71106.0739491|             142|              0.31161|         29737.0388991|       95465.98|   95430.3|                 0.0|        95407.068|95415.28700000001| 0.4182067077344284|
# |2026-01-18 21:57:00| 95430.3|95430.31|95420.67|95420.67|1.94868|2026-01-18 21:57:...|    185961.0200785|             532|              0.46079|          43973.312937|       95465.97|   95430.3|-1.00911345767588...|        95413.128|95415.28700000001| 0.2364626311143954|
# |2026-01-18 21:58:00|95420.67|95420.68|95420.67|95420.68|1.14835|2026-01-18 21:58:...|    109576.3348655|             153|               0.8471|          80830.858028|        95465.0|  95420.67|1.047990964092089...|         95421.26|95414.87500000001| 0.7376670875604128|
# |2026-01-18 21:59:00|95420.67|95430.45|95420.67|95430.44|1.56906|2026-01-18 21:59:...|    149729.4237569|             528|              1.25205|         119477.032599|        95465.0|  95420.68|1.022839074298078...|95422.89199999999|        95414.464| 0.7979618370234409|
# |2026-01-18 22:00:00|95430.45|95430.45|95420.67|95420.68|1.29393|2026-01-18 22:00:...|    123474.7905388|             525|              0.83612|         79789.4246865|        95465.0|  95430.44|-1.02273446502073...|        95426.478|95415.02900000001| 0.6461864243042513|
# +-------------------+--------+--------+--------+--------+-------+--------------------+------------------+----------------+---------------------+----------------------+---------------+----------+--------------------+-----------------+-----------------+-------------------+
# only showing top 20 rows
# root
#  |-- open_time: timestamp_ntz (nullable = true)
#  |-- open: double (nullable = true)
#  |-- high: double (nullable = true)
#  |-- low: double (nullable = true)
#  |-- close: double (nullable = true)
#  |-- volume: double (nullable = true)
#  |-- close_time: timestamp_ntz (nullable = true)
#  |-- quote_asset_volume: double (nullable = true)
#  |-- number_of_trades: long (nullable = true)
#  |-- taker_buy_base_volume: double (nullable = true)
#  |-- taker_buy_quote_volume: double (nullable = true)
#  |-- close_t_plus_10: double (nullable = true)
#  |-- prev_close: double (nullable = true)
#  |-- return: double (nullable = true)
#  |-- MA_5: double (nullable = true)
#  |-- MA_10: double (nullable = true)
#  |-- taker_ratio: double (nullable = true)

# %% [markdown]
# ### Save Data Silver :

# %%
def Save_Silver_Local(Data_B):
    Data_B.write.mode('overwrite').format("parquet").save("../../Data/Silver/")
    
Save_Silver_Local(df)
# Out:
# 26/01/21 09:55:28 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:28 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:28 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:28 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:28 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:28 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:28 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:28 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:28 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:28 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:28 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:28 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
# 26/01/21 09:55:28 WARN WindowExec: No Partition Defined for Window operation! Moving all data to a single partition, this can cause serious performance degradation.
